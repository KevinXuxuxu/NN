# %%
import numpy as np
import matplotlib.pyplot as plt
from src.model import Model
from src.activation import Identity

# %%
x = np.linspace(-4, 4, 1000)
y = np.sin(x)

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %%
m = Model(learning_rate=.001).layer(1).layer(10).layer(1, act=Identity)

# %%
x_shuffled = np.random.choice(np.linspace(-4,4,1000000), 200000)
y_shuffled = np.sin(x_shuffled)

# %%
cost = []
for i in range(0, 200000, 10):
    j = min(200000, i+10)
    xx = np.array([x_shuffled[i:j]]).T
    yy = np.array([y_shuffled[i:j]]).T
    m.inference(xx)
    cost.append(m.get_cost(yy))
    m.back_prop(yy)
fig, ax = plt.subplots()
ax.plot(np.linspace(0,1,len(cost)), np.array(cost))
plt.show()

# %%
y_prime = m.inference(x[:, np.newaxis])
fig, ax = plt.subplots()
ax.plot(x, y)
ax.plot(x, y_prime)
plt.show()
